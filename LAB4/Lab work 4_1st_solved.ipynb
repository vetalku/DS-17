# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 4: Work with data professionally!

# %% [markdown]
# ## Lab work 4

# %% [markdown]
# #### Мета:
#
# * навчитися обробляти дані
# * "парсити" сайти

# %% [markdown]
# ### Завдання 1:

# %% [markdown]
# #### Ознайомитися із API Національного банку
# https://old.bank.gov.ua/control/uk/publish/article?art_id=38441973&cat_id=38459171#exchange

# %% [markdown]
# 1. Підключитися до API.

# %%
import requests

# %% [markdown]
# 2. Отримати курс долара за останній рік.

# %%
from datetime import date
import dateutil.relativedelta

dt_today = date.today()
dt_year_ago = dt_today - dateutil.relativedelta.relativedelta(years=3)
params_line = {
    'start':dt_year_ago.strftime("%Y%m%d"),
    'end':dt_today.strftime("%Y%m%d"),
    'valcode':"usd",
    'sort':"exchangedate",
    'order':"desc",
    'format':'json'
}
print(params_line )

usd_exchange_rates = requests.api.get(f"https://bank.gov.ua/NBU_Exchange/exchange_site", params= params_line ).json()

print(usd_exchange_rates)
# Out:
# {'start': '20200313', 'end': '20230313', 'valcode': 'usd', 'sort': 'exchangedate', 'order': 'desc', 'format': 'json'}
# [{'exchangedate': '13.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '10.03.2023'}, {'exchangedate': '12.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '09.03.2023'}, {'exchangedate': '11.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '09.03.2023'}, {'exchangedate': '10.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '09.03.2023'}, {'exchangedate': '09.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '08.03.2023'}, {'exchangedate': '08.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '07.03.2023'}, {'exchangedate': '07.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '06.03.2023'}, {'exchangedate': '06.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '03.03.2023'}, {'exchangedate': '05.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '02.03.2023'}, {'exchangedate': '04.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '02.03.2023'}, {'exchangedate': '03.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '02.03.2023'}, {'exchangedate': '02.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '01.03.2023'}, {'exchangedate': '01.03.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '28.02.2023'}, {'exchangedate': '28.02.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '27.02.2023'}, {'exchangedate': '27.02.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '24.02.2023'}, {'exchangedate': '26.02.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '23.02.2023'}, {'exchangedate': '25.02.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '23.02.2023'}, {'exchangedate': '24.02.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '23.02.2023'}, {'exchangedate': '23.02.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '22.02.2023'}, {'exchangedate': '22.02.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'enname': 'US Dollar', 'rate': 36.5686, 'units': 1, 'rate_per_unit': 36.5686, 'group': '1', 'calcdate': '21.02.2023'}, {'exchangedate': '21.02.2023', 'r030': 840, 'cc': 'USD', 'txt': 'Долар США', 'e ...

# %% [markdown]
# 3. Вивести середнє значення та відхилення курсу за кожний місяць.

# %%
#import statistics
from math import sqrt

def list_avg(list_n):
    sum_n=0
    for n in list_n:
        sum_n+=n
    return sum_n/len(list_n)

def list_std(list_n):
    list_avg_n = list_avg(list_n)
    return sqrt((sum([pow((i-list_avg_n),2) for i in list_n])/len(list_n)))


for i in usd_exchange_rates:
    stat[i['exchangedate'][3:]]={'list':[], 
                                 'month_avg':0,
                                 'month_stdev':0
                                 }

for i in usd_exchange_rates:
    stat[i['exchangedate'][3:]]['list'].append(i['rate'])

for d in stat:
    stat[d]['month_avg'] = round(sum(stat[d]['list']) / len(stat[d]['list']),2)
    stat[d]['month_stdev'] = round(list_std(stat[d]['list']),2) #round(statistics.stdev(stat[d]['list']),2)

print(stat)
# Out:
# {'03.2023': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '02.2023': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '01.2023': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '12.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '11.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '10.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '09.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '08.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '07.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549], 'month_avg': 31.85, 'month_stdev': 3.5}, '06.2022': {'list': [29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549], 'month_avg': 29.25, 'month_stdev': 0.0}, '05.2022': {'list': [29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549], 'month_avg': 29.25, 'month_stdev': 0.0}, '04.2022': {'list': [29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549], 'month_avg': 29.25, 'month_stdev': 0.0}, '03.2022': {'list': [29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549,  ...

# %% [markdown]
# 4. Дану інформацію записати у файл за допомогою pickle.

# %%
import pickle 


with open("stat_data.pcl", "wb") as file1:
    pickle.dump(stat, file1)

# %%
with open("stat_data.pcl", "rb") as file1:
    loaded_data = pickle.load(file1)

print(loaded_data)
# Out:
# {'03.2023': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '02.2023': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '01.2023': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '12.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '11.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '10.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '09.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '08.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686], 'month_avg': 36.57, 'month_stdev': 0.0}, '07.2022': {'list': [36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 36.5686, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549], 'month_avg': 31.85, 'month_stdev': 3.5}, '06.2022': {'list': [29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549], 'month_avg': 29.25, 'month_stdev': 0.0}, '05.2022': {'list': [29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549], 'month_avg': 29.25, 'month_stdev': 0.0}, '04.2022': {'list': [29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549], 'month_avg': 29.25, 'month_stdev': 0.0}, '03.2022': {'list': [29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549, 29.2549,  ...

# %% [markdown]
# ### Завдання 2:

# %% [markdown]
# Потрібно проаналізувати всі товари на сайті:
# https://smallpacking.agrosem.ua/shop/

# %% [markdown]
# Створіть базу даних, що містить таблицю із такими стовбцями:
#     - артикул товару
#     - найменування
#     - ціна
#     - вага

# %% [markdown]
# ### Завдання 3:

# %% [markdown]
# Ознайомтеся із роботою SQLite та відповідним модулем у Python.
# Завантажте базу даних для виконання лабораторної роботи.
# Підключіться до завантаженої бази SQLite.

# %% [markdown]
# 1. Виведіть інформацію про дану базу.

# %% [markdown]
# 2. Виведіть перелік всіх таблиць.

# %% [markdown]
# 3. Список всіх cust_id з таблиці Customers table.

# %% [markdown]
# 4. Всю таблицю Customers table

# %% [markdown]
# 5. Список клієнтів (cust_names) відсортованих від Z до A

# %% [markdown]
# 6. Таблицю клієнтів та замовлень (cust_id і order_num) . Відсортуйте по клієнту і потім по даті замовлення

# %% [markdown]
# 7. Таблицю (на основі Items) з кількість та вартістю товару. Відсортуйте в порядку спадання по кількості та вартості

# %% [markdown]
# 8. Товар (з таблиці Products), ціна якого становить 9.49

# %% [markdown]
# 9. Виведіть назву товару та ціну, яка лежить в діапазоні від  3 до 6. Відсортуйте результат в по ціні в порядку зростання

# %% [markdown]
# 10. Кількість товару, що було продано

# %% [markdown]
# 11. Кількість найменувань товару, ціна якого більша за 4

# %% [markdown]
# 12. Розробіть алгоритм для виведення 3 найдорожчих товарів в базі

# %% [markdown]
# 13. Підрахуйте кількість замовлень для кожного клієнта використовуючи підзапити

# %% [markdown]
# 14. Виведіть список клієнтів та їх замовлення (використайте JOIN)

# %% [markdown]
# 15. Зробіть два запити: список товарів, ціна яких менша 5 та список товарів, ціна який більша рівна 5. Використайте UNION для об'єднання цих запитів

# %% [markdown]
# ### Завдання 4:

# %% [markdown]
# Зареєструйтеся на сайті  http://www.sql-ex.ru/
#
# Виконайте завдання із блоку SELECT; з 1 по 30 завдання
#
# Код запитів вставляйте сюди
