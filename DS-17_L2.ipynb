# %%
print("Hello World!!!")
# Out:
# Hello World!!!

# %%
# !git clone https://github.com/vetalku/DS-17.git
# Out:
# fatal: destination path 'DS-17' already exists and is not an empty directory.

# %%
print("fff")
# Out:
# fff

# %%
# !git push https://github.com/vetalku/DS-17.git@main
# Out:
# fatal: not a git repository (or any parent up to mount point /data)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
